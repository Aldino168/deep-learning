# %%
import torch
from torch import nn, optim
from jcopdl.callback import Callback, set_config

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
device= torch.device("cuda"if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# # Import Data

# %%
df=pd.read_csv("data/daily_min_temp.csv",index_col="Date",parse_dates=["Date"])
df
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %% [markdown]
# # Dataset Splitting

# %%
from sklearn.model_selection import train_test_split

# %%
ts_train, ts_test = train_test_split(df, test_size=0.2,shuffle=False)
ts_train.shape, ts_test.shape
# Out:
# ((2920, 1), (730, 1))

# %% [markdown]
# # Dataset and Dataloader

# %%
from jcopdl.utils.dataloader import TimeSeriesDataset
from torch.utils.data import DataLoader

# %%
seq_len= 14
bs=32

train_set= TimeSeriesDataset(ts_train,"Temp",seq_len)
trainloader=DataLoader(train_set,batch_size=bs)

test_set=TimeSeriesDataset(ts_test,"Temp",seq_len)
testloader= DataLoader(test_set,batch_size=bs)
# Out:
# (N, S, F): (208, 14, 1)
# Note: last 7 data excluded
#
# (N, S, F): (52, 14, 1)
# Note: last 1 data excluded

# %% [markdown]
# # Arsitektur and Config

# %%
class GRU (nn.Module):
    def __init__(self,input_size,output_size, hidden_size, num_layers, dropout):
        super().__init__()
        self.hidden= nn.GRU(input_size, hidden_size, num_layers, dropout=dropout, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
        
        
    def forward(self,x,hidden):
        x,hidden= self.hidden(x,hidden)
        x= self.fc(x)
        return x,hidden

# %%
config = set_config({
    "batch_size" : bs,
    "seq_len" : train_set.n_seq,
    "input_size" : train_set.n_feature,
    "output_size" : 1,
    "hidden_size" : 64,
    "num_layers" : 2,
    "dropout": 0
})

# %% [markdown]
# # Training Preparation ~> MCOC

# %%
model = GRU(config.input_size,config.output_size,config.hidden_size,config.num_layers,config.dropout).to(device)
criterion = nn.MSELoss(reduction="mean")
optimizer = optim.AdamW(model.parameters(), lr=0.001)
callback = Callback(model,config,outdir="model")

# %% [markdown]
# # Training Loop

# %%
def loop_fn (mode, dataset, dataloader, model, criterion, optimizer, device):
    if mode =="train":
        model.train()
    elif mode == "test":
        model.eval()
        
    cost = 0
    for feature,target in tqdm(dataloader,desc = mode.title()):
        feature, target = feature.to(device), target.to(device)
        output, hidden = model(feature,None) 
        loss = criterion(output, target)
        
        if mode == "train":
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            
        cost += loss.item()*feature.shape[0]
    cost=cost/len(dataset)
    return cost

# %%
from tqdm.auto import tqdm

# %%
while True :
    train_cost= loop_fn("train",train_set,trainloader,model,criterion,optimizer,device)
    with torch.no_grad():
        test_cost= loop_fn("test",test_set,testloader,model,criterion,optimizer,device)

    callback.log(train_cost, test_cost)


    callback.save_checkpoint()


    callback.cost_runtime_plotting()



    if callback.early_stopping(model, monitor='test_cost'):
        callback.plot_cost()
        break
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     1
# Train_cost  = 137.0133 | Test_cost  = 129.7188 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     2
# Train_cost  = 112.0089 | Test_cost  = 103.4159 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     3
# Train_cost  = 87.7255 | Test_cost  = 81.6985 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     4
# Train_cost  = 69.9195 | Test_cost  = 67.9386 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     5
# Train_cost  = 58.8079 | Test_cost  = 58.8087 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     6
# Train_cost  = 51.0888 | Test_cost  = 51.8163 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     7
# Train_cost  = 45.0245 | Test_cost  = 46.0632 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     8
# Train_cost  = 40.0066 | Test_cost  = 41.2098 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     9
# Train_cost  = 35.7845 | Test_cost  = 37.0851 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    10
# Train_cost  = 32.2200 | Test_cost  = 33.5796 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    11
# Train_cost  = 29.2178 | Test_cost  = 30.6101 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    12
# Train_cost  = 26.7022 | Test_cost  = 28.1074 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    13
# Train_cost  = 24.6086 | Test_cost  = 26.0109 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    14
# Train_cost  = 22.8801 | Test_cost  = 24.2665 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    15
# Train_cost  = 21.4650 | Test_cost  = 22.8250 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    16
# Train_cost  = 20.3170 | Test_cost  = 21.6419 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    17
# Train_cost  = 19.3940 | Test_cost  = 20.6773 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    18
# Train_cost  = 18.6587 | Test_cost  = 19.8956 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    19
# Train_cost  = 18.0782 | Test_cost  = 19.2658 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    20
# Train_cost  = 17.6240 | Test_cost  = 18.7609 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    21
# Train_cost  = 17.2715 | Test_cost  = 18.3579 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    22
# Train_cost  = 17.0002 | Test_cost  = 18.0374 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    23
# Train_cost  = 16.7929 | Test_cost  = 17.7832 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    24
# Train_cost  = 16.6356 | Test_cost  = 17.5820 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    25
# Train_cost  = 16.5170 | Test_cost  = 17.4228 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    26
# Train_cost  = 16.4278 | Test_cost  = 17.2968 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    27
# Train_cost  = 16.3610 | Test_cost  = 17.1970 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    28
# Train_cost  = 16.3109 | Test_cost  = 17.1178 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    29
# Train_cost  = 16.2732 | Test_cost  = 17.0548 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    30
# Train_cost  = 16.2447 | Test_cost  = 17.0044 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    31
# Train_cost  = 16.2228 | Test_cost  = 16.9639 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    32
# Train_cost  = 16.2057 | Test_cost  = 16.9311 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    33
# Train_cost  = 16.1920 | Test_cost  = 16.9043 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    34
# Train_cost  = 16.1806 | Test_cost  = 16.8823 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    35
# Train_cost  = 16.1707 | Test_cost  = 16.8639 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    36
# Train_cost  = 16.1618 | Test_cost  = 16.8481 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    37
# Train_cost  = 16.1534 | Test_cost  = 16.8344 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    38
# Train_cost  = 16.1449 | Test_cost  = 16.8219 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    39
# Train_cost  = 16.1359 | Test_cost  = 16.8099 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    40
# Train_cost  = 16.1257 | Test_cost  = 16.7974 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    41
# Train_cost  = 16.1136 | Test_cost  = 16.7833 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    42
# Train_cost  = 16.0977 | Test_cost  = 16.7651 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    43
# Train_cost  = 16.0749 | Test_cost  = 16.7385 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    44
# Train_cost  = 16.0398 | Test_cost  = 16.6963 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    45
# Train_cost  = 15.9817 | Test_cost  = 16.6175 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    46
# Train_cost  = 15.8627 | Test_cost  = 16.4201 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    47
# Train_cost  = 15.5494 | Test_cost  = 15.9144 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    48
# Train_cost  = 14.8509 | Test_cost  = 15.2120 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    49
# Train_cost  = 13.9361 | Test_cost  = 14.2348 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    50
# Train_cost  = 12.9967 | Test_cost  = 13.3623 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    51
# Train_cost  = 12.4060 | Test_cost  = 12.7603 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    52
# Train_cost  = 11.9062 | Test_cost  = 12.1638 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    53
# Train_cost  = 11.4033 | Test_cost  = 11.5759 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    54
# Train_cost  = 10.9353 | Test_cost  = 11.0217 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    55
# Train_cost  = 10.5011 | Test_cost  = 10.4776 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    56
# Train_cost  = 10.0764 | Test_cost  = 9.9624 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    57
# Train_cost  = 9.6877 | Test_cost  = 9.4925 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    58
# Train_cost  = 9.3471 | Test_cost  = 9.0978 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    59
# Train_cost  = 9.0652 | Test_cost  = 8.7584 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    60
# Train_cost  = 8.8244 | Test_cost  = 8.4563 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    61
# Train_cost  = 8.6078 | Test_cost  = 8.1931 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    62
# Train_cost  = 8.4150 | Test_cost  = 7.9642 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    63
# Train_cost  = 8.2470 | Test_cost  = 7.7607 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    64
# Train_cost  = 8.0984 | Test_cost  = 7.5784 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    65
# Train_cost  = 7.9648 | Test_cost  = 7.4168 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    66
# Train_cost  = 7.8450 | Test_cost  = 7.2736 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    67
# Train_cost  = 7.7375 | Test_cost  = 7.1458 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    68
# Train_cost  = 7.6403 | Test_cost  = 7.0316 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    69
# Train_cost  = 7.5522 | Test_cost  = 6.9291 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    70
# Train_cost  = 7.4727 | Test_cost  = 6.8360 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    71
# Train_cost  = 7.4006 | Test_cost  = 6.7507 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    72
# Train_cost  = 7.3349 | Test_cost  = 6.6722 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    73
# Train_cost  = 7.2746 | Test_cost  = 6.5994 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    74
# Train_cost  = 7.2190 | Test_cost  = 6.5317 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    75
# Train_cost  = 7.1675 | Test_cost  = 6.4684 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    76
# Train_cost  = 7.1196 | Test_cost  = 6.4091 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    77
# Train_cost  = 7.0749 | Test_cost  = 6.3534 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    78
# Train_cost  = 7.0330 | Test_cost  = 6.3011 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    79
# Train_cost  = 6.9937 | Test_cost  = 6.2518 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    80
# Train_cost  = 6.9568 | Test_cost  = 6.2053 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    81
# Train_cost  = 6.9221 | Test_cost  = 6.1614 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    82
# Train_cost  = 6.8894 | Test_cost  = 6.1199 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    83
# Train_cost  = 6.8585 | Test_cost  = 6.0805 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    84
# Train_cost  = 6.8293 | Test_cost  = 6.0431 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    85
# Train_cost  = 6.8014 | Test_cost  = 6.0076 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    86
# Train_cost  = 6.7749 | Test_cost  = 5.9738 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    87
# Train_cost  = 6.7495 | Test_cost  = 5.9416 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    88
# Train_cost  = 6.7251 | Test_cost  = 5.9108 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    89
# Train_cost  = 6.7015 | Test_cost  = 5.8815 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    90
# Train_cost  = 6.6787 | Test_cost  = 5.8533 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    91
# Train_cost  = 6.6567 | Test_cost  = 5.8262 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    92
# Train_cost  = 6.6356 | Test_cost  = 5.8000 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    93
# Train_cost  = 6.6153 | Test_cost  = 5.7746 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    94
# Train_cost  = 6.5959 | Test_cost  = 5.7501 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    95
# Train_cost  = 6.5772 | Test_cost  = 5.7264 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    96
# Train_cost  = 6.5594 | Test_cost  = 5.7035 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    97
# Train_cost  = 6.5422 | Test_cost  = 5.6813 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    98
# Train_cost  = 6.5256 | Test_cost  = 5.6599 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    99
# Train_cost  = 6.5096 | Test_cost  = 5.6393 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   100
# Train_cost  = 6.4942 | Test_cost  = 5.6193 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   101
# Train_cost  = 6.4794 | Test_cost  = 5.6001 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   102
# Train_cost  = 6.4652 | Test_cost  = 5.5814 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   103
# Train_cost  = 6.4514 | Test_cost  = 5.5634 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   104
# Train_cost  = 6.4381 | Test_cost  = 5.5460 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   105
# Train_cost  = 6.4253 | Test_cost  = 5.5290 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   106
# Train_cost  = 6.4129 | Test_cost  = 5.5126 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   107
# Train_cost  = 6.4009 | Test_cost  = 5.4967 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   108
# Train_cost  = 6.3892 | Test_cost  = 5.4813 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   109
# Train_cost  = 6.3779 | Test_cost  = 5.4664 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   110
# Train_cost  = 6.3669 | Test_cost  = 5.4519 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   111
# Train_cost  = 6.3563 | Test_cost  = 5.4378 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   112
# Train_cost  = 6.3459 | Test_cost  = 5.4241 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   113
# Train_cost  = 6.3359 | Test_cost  = 5.4109 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   114
# Train_cost  = 6.3261 | Test_cost  = 5.3982 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   115
# Train_cost  = 6.3166 | Test_cost  = 5.3858 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   116
# Train_cost  = 6.3074 | Test_cost  = 5.3739 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   117
# Train_cost  = 6.2985 | Test_cost  = 5.3624 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   118
# Train_cost  = 6.2897 | Test_cost  = 5.3513 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   119
# Train_cost  = 6.2812 | Test_cost  = 5.3405 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   120
# Train_cost  = 6.2728 | Test_cost  = 5.3302 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   121
# Train_cost  = 6.2647 | Test_cost  = 5.3204 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   122
# Train_cost  = 6.2566 | Test_cost  = 5.3112 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   123
# Train_cost  = 6.2485 | Test_cost  = 5.3024 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   124
# Train_cost  = 6.2405 | Test_cost  = 5.2943 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   125
# Train_cost  = 6.2325 | Test_cost  = 5.2866 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   126
# Train_cost  = 6.2246 | Test_cost  = 5.2790 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   127
# Train_cost  = 6.2171 | Test_cost  = 5.2714 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   128
# Train_cost  = 6.2100 | Test_cost  = 5.2635 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   129
# Train_cost  = 6.2033 | Test_cost  = 5.2554 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   130
# Train_cost  = 6.1969 | Test_cost  = 5.2471 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   131
# Train_cost  = 6.1906 | Test_cost  = 5.2387 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   132
# Train_cost  = 6.1843 | Test_cost  = 5.2306 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   133
# Train_cost  = 6.1781 | Test_cost  = 5.2226 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   134
# Train_cost  = 6.1720 | Test_cost  = 5.2149 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   135
# Train_cost  = 6.1660 | Test_cost  = 5.2076 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   136
# Train_cost  = 6.1602 | Test_cost  = 5.2005 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   137
# Train_cost  = 6.1546 | Test_cost  = 5.1937 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   138
# Train_cost  = 6.1491 | Test_cost  = 5.1870 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   139
# Train_cost  = 6.1437 | Test_cost  = 5.1806 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   140
# Train_cost  = 6.1385 | Test_cost  = 5.1743 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   141
# Train_cost  = 6.1334 | Test_cost  = 5.1683 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   142
# Train_cost  = 6.1284 | Test_cost  = 5.1623 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   143
# Train_cost  = 6.1234 | Test_cost  = 5.1566 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   144
# Train_cost  = 6.1186 | Test_cost  = 5.1509 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   145
# Train_cost  = 6.1139 | Test_cost  = 5.1455 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   146
# Train_cost  = 6.1092 | Test_cost  = 5.1401 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   147
# Train_cost  = 6.1047 | Test_cost  = 5.1349 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   148
# Train_cost  = 6.1002 | Test_cost  = 5.1298 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   149
# Train_cost  = 6.0958 | Test_cost  = 5.1249 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   150
# Train_cost  = 6.0914 | Test_cost  = 5.1201 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   151
# Train_cost  = 6.0872 | Test_cost  = 5.1154 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   152
# Train_cost  = 6.0830 | Test_cost  = 5.1109 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   153
# Train_cost  = 6.0789 | Test_cost  = 5.1065 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   154
# Train_cost  = 6.0748 | Test_cost  = 5.1023 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   155
# Train_cost  = 6.0708 | Test_cost  = 5.0982 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   156
# Train_cost  = 6.0668 | Test_cost  = 5.0942 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   157
# Train_cost  = 6.0629 | Test_cost  = 5.0904 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   158
# Train_cost  = 6.0590 | Test_cost  = 5.0866 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   159
# Train_cost  = 6.0552 | Test_cost  = 5.0830 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   160
# Train_cost  = 6.0515 | Test_cost  = 5.0795 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   161
# Train_cost  = 6.0477 | Test_cost  = 5.0761 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   162
# Train_cost  = 6.0440 | Test_cost  = 5.0728 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   163
# Train_cost  = 6.0404 | Test_cost  = 5.0696 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   164
# Train_cost  = 6.0368 | Test_cost  = 5.0665 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   165
# Train_cost  = 6.0332 | Test_cost  = 5.0635 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   166
# Train_cost  = 6.0296 | Test_cost  = 5.0606 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   167
# Train_cost  = 6.0261 | Test_cost  = 5.0578 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   168
# Train_cost  = 6.0225 | Test_cost  = 5.0551 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   169
# Train_cost  = 6.0190 | Test_cost  = 5.0525 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   170
# Train_cost  = 6.0156 | Test_cost  = 5.0500 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   171
# Train_cost  = 6.0121 | Test_cost  = 5.0476 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   172
# Train_cost  = 6.0087 | Test_cost  = 5.0452 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   173
# Train_cost  = 6.0053 | Test_cost  = 5.0430 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   174
# Train_cost  = 6.0019 | Test_cost  = 5.0408 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   175
# Train_cost  = 5.9985 | Test_cost  = 5.0387 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   176
# Train_cost  = 5.9952 | Test_cost  = 5.0367 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   177
# Train_cost  = 5.9919 | Test_cost  = 5.0348 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   178
# Train_cost  = 5.9886 | Test_cost  = 5.0329 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   179
# Train_cost  = 5.9853 | Test_cost  = 5.0311 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   180
# Train_cost  = 5.9820 | Test_cost  = 5.0294 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   181
# Train_cost  = 5.9787 | Test_cost  = 5.0278 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   182
# Train_cost  = 5.9754 | Test_cost  = 5.0262 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   183
# Train_cost  = 5.9722 | Test_cost  = 5.0247 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   184
# Train_cost  = 5.9689 | Test_cost  = 5.0232 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   185
# Train_cost  = 5.9657 | Test_cost  = 5.0218 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   186
# Train_cost  = 5.9624 | Test_cost  = 5.0204 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   187
# Train_cost  = 5.9592 | Test_cost  = 5.0191 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   188
# Train_cost  = 5.9560 | Test_cost  = 5.0178 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   189
# Train_cost  = 5.9528 | Test_cost  = 5.0166 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   190
# Train_cost  = 5.9495 | Test_cost  = 5.0154 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   191
# Train_cost  = 5.9463 | Test_cost  = 5.0143 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   192
# Train_cost  = 5.9431 | Test_cost  = 5.0131 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   193
# Train_cost  = 5.9399 | Test_cost  = 5.0121 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   194
# Train_cost  = 5.9366 | Test_cost  = 5.0110 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   195
# Train_cost  = 5.9334 | Test_cost  = 5.0100 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   196
# Train_cost  = 5.9301 | Test_cost  = 5.0090 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   197
# Train_cost  = 5.9268 | Test_cost  = 5.0081 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   198
# Train_cost  = 5.9235 | Test_cost  = 5.0072 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   199
# Train_cost  = 5.9202 | Test_cost  = 5.0063 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   200
# Train_cost  = 5.9169 | Test_cost  = 5.0055 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   201
# Train_cost  = 5.9135 | Test_cost  = 5.0047 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   202
# Train_cost  = 5.9101 | Test_cost  = 5.0039 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   203
# Train_cost  = 5.9067 | Test_cost  = 5.0032 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   204
# Train_cost  = 5.9033 | Test_cost  = 5.0025 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   205
# Train_cost  = 5.8998 | Test_cost  = 5.0019 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   206
# Train_cost  = 5.8963 | Test_cost  = 5.0014 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   207
# Train_cost  = 5.8928 | Test_cost  = 5.0008 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   208
# Train_cost  = 5.8892 | Test_cost  = 5.0004 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   209
# Train_cost  = 5.8856 | Test_cost  = 4.9999 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   210
# Train_cost  = 5.8820 | Test_cost  = 4.9996 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   211
# Train_cost  = 5.8783 | Test_cost  = 4.9992 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   212
# Train_cost  = 5.8746 | Test_cost  = 4.9989 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   213
# Train_cost  = 5.8709 | Test_cost  = 4.9987 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   214
# Train_cost  = 5.8671 | Test_cost  = 4.9985 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   215
# Train_cost  = 5.8633 | Test_cost  = 4.9983 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   216
# Train_cost  = 5.8594 | Test_cost  = 4.9982 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   217
# Train_cost  = 5.8556 | Test_cost  = 4.9981 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   218
# Train_cost  = 5.8516 | Test_cost  = 4.9981 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   219
# Train_cost  = 5.8477 | Test_cost  = 4.9981 |
# ==> EarlyStop patience =  1 | Best test_cost: 4.9981
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   220
# Train_cost  = 5.8437 | Test_cost  = 4.9981 |
# ==> EarlyStop patience =  2 | Best test_cost: 4.9981
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   221
# Train_cost  = 5.8397 | Test_cost  = 4.9982 |
# ==> EarlyStop patience =  3 | Best test_cost: 4.9981
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   222
# Train_cost  = 5.8356 | Test_cost  = 4.9984 |
# ==> EarlyStop patience =  4 | Best test_cost: 4.9981
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   223
# Train_cost  = 5.8316 | Test_cost  = 4.9985 |
# ==> EarlyStop patience =  5 | Best test_cost: 4.9981
# ==> Execute Early Stopping at epoch: 223 | Best test_cost: 4.9981
# ==> Best model is saved at model

# %%
from luwiji.rnn import illustration

# %%
illustration.forecast

# %% [markdown]
# forcast untuk data time series itu sangat susah untuk diwujudkan dalam memprediksi dalam jangka panjang, karna apa? karna coba kita pahami illustrasi diatas, dimana pada saat training (menggunakan data untuk prediksi) model kita menggunakan data hari senin untuk memprediksi data hari selasa yang mana data hari selasa kita udah ada dalam dataset training kita, maka nya machine dapat memprediksi data yang ada (ya karna dia update weight, backprop, dll), tapi coba kita telaah lebih lanjut kalau misal nya kita hanya punya data yang dipelajari sampe hari rabu, kita coba untuk menggunakan insight dari data hari seni - rabu itu untuk memprediksi hari kamis dan selanjut nya, maka secara logika model machine kita akan kesusahan atau memiliki error prediksi yang tinggi, karna apa? karna informasi dari data data lalu (senin - rabu) itu gak terlalu bermakna, logika nya gini deh "kalau saya tau suhu di hari rabu, apakah saya bisa tau suhu di hari kamis? kemungkinan besar kita akan salah memprediksi nya" karna apa? karna informasi dari kita hanya mempelajari data data sebelum nya belum menjamin dapat memprediksi data data dikemudian hari selama nya.
# * maka dari itu kita perlu membuat data kita lebih bermakna, seperti kita bagi data misal nya berdasarkan quarter dalam satu tahun, maka itu setidak nya memberikan pola baru kepada machine dalam mempelajari pola.
# * menggunakan metode pengembangan dari Recurrent Neural Network juga bisa menjadi solusi nya

# %%
from utils import data4pred,pred4pred

# %%
train_forecast_set = TimeSeriesDataset(ts_train,"Temp",1)
trainforcastloader= DataLoader(train_forecast_set)
test_forecast_set = TimeSeriesDataset(ts_test,"Temp",1)
testforcastloader= DataLoader(test_forecast_set)
# Out:
# (N, S, F): (2919, 1, 1)
# Note: last 0 data excluded
#
# (N, S, F): (729, 1, 1)
# Note: last 0 data excluded

# %%
# data4pred
plt.figure(figsize=(15,10))

plt.subplot(211)
data4pred(model,train_forecast_set,trainforcastloader,device)
plt.title("train")


plt.subplot(212)
data4pred(model,test_forecast_set,testforcastloader,device)
plt.title("test")
# Out:
# C:\Users\Rahmat\anaconda3\envs\jcop\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'test')

# %%
plt.figure(figsize=(15,5))

pred4pred(model,test_forecast_set,testforcastloader,device)
plt.title("test")
# Out:
# Text(0.5, 1.0, 'test')
