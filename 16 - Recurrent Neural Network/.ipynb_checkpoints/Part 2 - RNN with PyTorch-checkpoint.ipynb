# %%
import torch
from torch import nn, optim
from jcopdl.callback import Callback, set_config

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
device= torch.device("cuda"if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# # Import Data

# %%
df=pd.read_csv("data/daily_min_temp.csv",index_col="Date",parse_dates=["Date"])
df
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %% [markdown]
# # Dataset Splitting

# %%
from sklearn.model_selection import train_test_split

# %%
ts_train, ts_test = train_test_split(df, test_size=0.2,shuffle=False)
ts_train.shape, ts_test.shape
# Out:
# ((2920, 1), (730, 1))

# %% [markdown]
# # Dataset and Dataloader

# %%
from jcopdl.utils.dataloader import TimeSeriesDataset
from torch.utils.data import DataLoader

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
seq_len= 14
bs=32

train_set= TimeSeriesDataset(ts_train,"Temp",seq_len)
trainloader=DataLoader(train_set,batch_size=bs)

test_set=TimeSeriesDataset(ts_test,"Temp",seq_len)
testloader= DataLoader(test_set,batch_size=bs)
# Out:
# (N, S, F): (208, 14, 1)
# Note: last 7 data excluded
#
# (N, S, F): (52, 14, 1)
# Note: last 1 data excluded

# %% [markdown]
# # Arsitektur and Config

# %%
class RNN (nn.Module):
    def __init__(self,input_size,output_size, hidden_size, num_layers, dropout):
        super().__init__()
        self.hidden= nn.RNN(input_size, hidden_size, num_layers, dropout=dropout, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
        
        
    def forward(self,x,hidden):
        x,hidden= self.hidden(x,hidden)
        x= self.fc(x)
        return x,hidden

# %%
config = set_config({
    "batch_size" : bs,
    "seq_len" : train_set.n_seq,
    "input_size" : train_set.n_feature,
    "output_size" : 1,
    "hidden_size" : 64,
    "num_layers" : 2,
    "dropout": 0
})

# %% [markdown]
# # Training Preparation ~> MCOC

# %%
model = RNN(config.input_size,config.output_size,config.hidden_size,config.num_layers,config.dropout).to(device)
criterion = nn.MSELoss(reduction="mean")
optimizer = optim.AdamW(model.parameters(), lr=0.001)
callback = Callback(model,config,outdir="model")

# %% [markdown]
# # Training Loop

# %%
def loop_fn (mode, dataset, dataloader, model, criterion, optimizer, device):
    if mode =="train":
        model.train()
    elif mode == "test":
        model.eval()
        
    cost = 0
    for feature,target in tqdm(dataloader,desc = mode.title()):
        feature, target = feature.to(device), target.to(device)
        output, hidden = model(feature,None) 
        loss = criterion(output, target)
        
        if mode == "train":
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            
        cost += loss.item()*feature.shape[0]
    cost=cost/len(dataset)
    return cost

# %%
from tqdm.auto import tqdm

# %%
while True :
    train_cost= loop_fn("train",train_set,trainloader,model,criterion,optimizer,device)
    with torch.no_grad():
        test_cost= loop_fn("test",test_set,testloader,model,criterion,optimizer,device)

    callback.log(train_cost, test_cost)


    callback.save_checkpoint()


    callback.cost_runtime_plotting()



    if callback.early_stopping(model, monitor='test_cost'):
        callback.plot_cost()
        break
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     1
# Train_cost  = 133.3656 | Test_cost  = 117.2954 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     2
# Train_cost  = 97.0347 | Test_cost  = 85.3617 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     3
# Train_cost  = 70.9727 | Test_cost  = 66.1653 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     4
# Train_cost  = 56.5644 | Test_cost  = 55.9146 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     5
# Train_cost  = 48.3657 | Test_cost  = 48.9866 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     6
# Train_cost  = 42.4762 | Test_cost  = 43.5164 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     7
# Train_cost  = 37.7368 | Test_cost  = 38.9531 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     8
# Train_cost  = 33.7863 | Test_cost  = 35.0982 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     9
# Train_cost  = 30.4744 | Test_cost  = 31.8411 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    10
# Train_cost  = 27.7053 | Test_cost  = 29.1000 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    11
# Train_cost  = 25.4044 | Test_cost  = 26.8068 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    12
# Train_cost  = 23.5071 | Test_cost  = 24.9007 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    13
# Train_cost  = 21.9556 | Test_cost  = 23.3268 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    14
# Train_cost  = 20.6978 | Test_cost  = 22.0358 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    15
# Train_cost  = 19.6873 | Test_cost  = 20.9839 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    16
# Train_cost  = 18.8829 | Test_cost  = 20.1322 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    17
# Train_cost  = 18.2487 | Test_cost  = 19.4470 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    18
# Train_cost  = 17.7534 | Test_cost  = 18.8988 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    19
# Train_cost  = 17.3703 | Test_cost  = 18.4625 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    20
# Train_cost  = 17.0767 | Test_cost  = 18.1169 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    21
# Train_cost  = 16.8537 | Test_cost  = 17.8440 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    22
# Train_cost  = 16.6859 | Test_cost  = 17.6292 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    23
# Train_cost  = 16.5605 | Test_cost  = 17.4604 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    24
# Train_cost  = 16.4674 | Test_cost  = 17.3278 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    25
# Train_cost  = 16.3987 | Test_cost  = 17.2237 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    26
# Train_cost  = 16.3481 | Test_cost  = 17.1418 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    27
# Train_cost  = 16.3109 | Test_cost  = 17.0772 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    28
# Train_cost  = 16.2833 | Test_cost  = 17.0261 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    29
# Train_cost  = 16.2627 | Test_cost  = 16.9854 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    30
# Train_cost  = 16.2470 | Test_cost  = 16.9528 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    31
# Train_cost  = 16.2347 | Test_cost  = 16.9265 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    32
# Train_cost  = 16.2247 | Test_cost  = 16.9050 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    33
# Train_cost  = 16.2162 | Test_cost  = 16.8870 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    34
# Train_cost  = 16.2084 | Test_cost  = 16.8718 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    35
# Train_cost  = 16.2010 | Test_cost  = 16.8583 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    36
# Train_cost  = 16.1933 | Test_cost  = 16.8461 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    37
# Train_cost  = 16.1851 | Test_cost  = 16.8342 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    38
# Train_cost  = 16.1756 | Test_cost  = 16.8220 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    39
# Train_cost  = 16.1642 | Test_cost  = 16.8083 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    40
# Train_cost  = 16.1496 | Test_cost  = 16.7917 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    41
# Train_cost  = 16.1300 | Test_cost  = 16.7693 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    42
# Train_cost  = 16.1000 | Test_cost  = 16.7307 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    43
# Train_cost  = 16.0409 | Test_cost  = 16.6405 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    44
# Train_cost  = 15.8907 | Test_cost  = 16.3822 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    45
# Train_cost  = 15.4619 | Test_cost  = 15.7900 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    46
# Train_cost  = 14.5520 | Test_cost  = 14.9011 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    47
# Train_cost  = 13.6046 | Test_cost  = 14.0151 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    48
# Train_cost  = 12.9476 | Test_cost  = 13.0661 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    49
# Train_cost  = 12.1730 | Test_cost  = 12.2471 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    50
# Train_cost  = 11.5852 | Test_cost  = 11.6519 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    51
# Train_cost  = 11.1398 | Test_cost  = 11.0309 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    52
# Train_cost  = 10.6620 | Test_cost  = 10.5335 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    53
# Train_cost  = 10.2546 | Test_cost  = 10.1080 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    54
# Train_cost  = 9.9223 | Test_cost  = 9.6936 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    55
# Train_cost  = 9.6109 | Test_cost  = 9.3090 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    56
# Train_cost  = 9.3239 | Test_cost  = 8.9813 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    57
# Train_cost  = 9.0867 | Test_cost  = 8.7057 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    58
# Train_cost  = 8.8980 | Test_cost  = 8.4620 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    59
# Train_cost  = 8.7356 | Test_cost  = 8.2351 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    60
# Train_cost  = 8.5783 | Test_cost  = 8.0302 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    61
# Train_cost  = 8.4228 | Test_cost  = 7.8537 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    62
# Train_cost  = 8.2829 | Test_cost  = 7.6985 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    63
# Train_cost  = 8.1648 | Test_cost  = 7.5552 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    64
# Train_cost  = 8.0590 | Test_cost  = 7.4200 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    65
# Train_cost  = 7.9552 | Test_cost  = 7.2956 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    66
# Train_cost  = 7.8538 | Test_cost  = 7.1831 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    67
# Train_cost  = 7.7608 | Test_cost  = 7.0810 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    68
# Train_cost  = 7.6777 | Test_cost  = 6.9872 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    69
# Train_cost  = 7.6022 | Test_cost  = 6.9002 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    70
# Train_cost  = 7.5324 | Test_cost  = 6.8198 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    71
# Train_cost  = 7.4678 | Test_cost  = 6.7455 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    72
# Train_cost  = 7.4084 | Test_cost  = 6.6764 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    73
# Train_cost  = 7.3535 | Test_cost  = 6.6119 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    74
# Train_cost  = 7.3023 | Test_cost  = 6.5514 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    75
# Train_cost  = 7.2543 | Test_cost  = 6.4944 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    76
# Train_cost  = 7.2092 | Test_cost  = 6.4408 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    77
# Train_cost  = 7.1667 | Test_cost  = 6.3903 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    78
# Train_cost  = 7.1267 | Test_cost  = 6.3425 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    79
# Train_cost  = 7.0889 | Test_cost  = 6.2974 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    80
# Train_cost  = 7.0530 | Test_cost  = 6.2546 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    81
# Train_cost  = 7.0189 | Test_cost  = 6.2142 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    82
# Train_cost  = 6.9866 | Test_cost  = 6.1758 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    83
# Train_cost  = 6.9558 | Test_cost  = 6.1394 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    84
# Train_cost  = 6.9266 | Test_cost  = 6.1048 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    85
# Train_cost  = 6.8988 | Test_cost  = 6.0720 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    86
# Train_cost  = 6.8723 | Test_cost  = 6.0408 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    87
# Train_cost  = 6.8471 | Test_cost  = 6.0111 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    88
# Train_cost  = 6.8231 | Test_cost  = 5.9828 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    89
# Train_cost  = 6.8002 | Test_cost  = 5.9559 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    90
# Train_cost  = 6.7784 | Test_cost  = 5.9302 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    91
# Train_cost  = 6.7575 | Test_cost  = 5.9058 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    92
# Train_cost  = 6.7376 | Test_cost  = 5.8824 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    93
# Train_cost  = 6.7186 | Test_cost  = 5.8600 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    94
# Train_cost  = 6.7004 | Test_cost  = 5.8386 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    95
# Train_cost  = 6.6829 | Test_cost  = 5.8182 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    96
# Train_cost  = 6.6663 | Test_cost  = 5.7985 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    97
# Train_cost  = 6.6503 | Test_cost  = 5.7797 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    98
# Train_cost  = 6.6349 | Test_cost  = 5.7616 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    99
# Train_cost  = 6.6202 | Test_cost  = 5.7442 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   100
# Train_cost  = 6.6060 | Test_cost  = 5.7275 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   101
# Train_cost  = 6.5924 | Test_cost  = 5.7114 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   102
# Train_cost  = 6.5793 | Test_cost  = 5.6958 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   103
# Train_cost  = 6.5666 | Test_cost  = 5.6808 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   104
# Train_cost  = 6.5544 | Test_cost  = 5.6663 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   105
# Train_cost  = 6.5426 | Test_cost  = 5.6523 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   106
# Train_cost  = 6.5312 | Test_cost  = 5.6388 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   107
# Train_cost  = 6.5201 | Test_cost  = 5.6257 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   108
# Train_cost  = 6.5094 | Test_cost  = 5.6130 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   109
# Train_cost  = 6.4990 | Test_cost  = 5.6007 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   110
# Train_cost  = 6.4890 | Test_cost  = 5.5888 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   111
# Train_cost  = 6.4792 | Test_cost  = 5.5773 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   112
# Train_cost  = 6.4697 | Test_cost  = 5.5661 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   113
# Train_cost  = 6.4605 | Test_cost  = 5.5552 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   114
# Train_cost  = 6.4515 | Test_cost  = 5.5447 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   115
# Train_cost  = 6.4427 | Test_cost  = 5.5344 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   116
# Train_cost  = 6.4342 | Test_cost  = 5.5245 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   117
# Train_cost  = 6.4259 | Test_cost  = 5.5148 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   118
# Train_cost  = 6.4177 | Test_cost  = 5.5054 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   119
# Train_cost  = 6.4098 | Test_cost  = 5.4963 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   120
# Train_cost  = 6.4021 | Test_cost  = 5.4874 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   121
# Train_cost  = 6.3945 | Test_cost  = 5.4788 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   122
# Train_cost  = 6.3871 | Test_cost  = 5.4704 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   123
# Train_cost  = 6.3799 | Test_cost  = 5.4622 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   124
# Train_cost  = 6.3728 | Test_cost  = 5.4543 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   125
# Train_cost  = 6.3659 | Test_cost  = 5.4466 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   126
# Train_cost  = 6.3591 | Test_cost  = 5.4392 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   127
# Train_cost  = 6.3524 | Test_cost  = 5.4319 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   128
# Train_cost  = 6.3459 | Test_cost  = 5.4248 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   129
# Train_cost  = 6.3395 | Test_cost  = 5.4180 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   130
# Train_cost  = 6.3333 | Test_cost  = 5.4113 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   131
# Train_cost  = 6.3271 | Test_cost  = 5.4048 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   132
# Train_cost  = 6.3211 | Test_cost  = 5.3986 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   133
# Train_cost  = 6.3152 | Test_cost  = 5.3925 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   134
# Train_cost  = 6.3093 | Test_cost  = 5.3866 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   135
# Train_cost  = 6.3036 | Test_cost  = 5.3809 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   136
# Train_cost  = 6.2980 | Test_cost  = 5.3753 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   137
# Train_cost  = 6.2925 | Test_cost  = 5.3699 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   138
# Train_cost  = 6.2871 | Test_cost  = 5.3647 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   139
# Train_cost  = 6.2817 | Test_cost  = 5.3597 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   140
# Train_cost  = 6.2765 | Test_cost  = 5.3548 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   141
# Train_cost  = 6.2713 | Test_cost  = 5.3501 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   142
# Train_cost  = 6.2662 | Test_cost  = 5.3456 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   143
# Train_cost  = 6.2612 | Test_cost  = 5.3412 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   144
# Train_cost  = 6.2562 | Test_cost  = 5.3370 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   145
# Train_cost  = 6.2514 | Test_cost  = 5.3329 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   146
# Train_cost  = 6.2466 | Test_cost  = 5.3289 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   147
# Train_cost  = 6.2419 | Test_cost  = 5.3252 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   148
# Train_cost  = 6.2372 | Test_cost  = 5.3215 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   149
# Train_cost  = 6.2326 | Test_cost  = 5.3180 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   150
# Train_cost  = 6.2281 | Test_cost  = 5.3146 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   151
# Train_cost  = 6.2236 | Test_cost  = 5.3114 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   152
# Train_cost  = 6.2192 | Test_cost  = 5.3083 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   153
# Train_cost  = 6.2148 | Test_cost  = 5.3053 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   154
# Train_cost  = 6.2105 | Test_cost  = 5.3025 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   155
# Train_cost  = 6.2063 | Test_cost  = 5.2997 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   156
# Train_cost  = 6.2021 | Test_cost  = 5.2971 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   157
# Train_cost  = 6.1979 | Test_cost  = 5.2946 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   158
# Train_cost  = 6.1938 | Test_cost  = 5.2922 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   159
# Train_cost  = 6.1897 | Test_cost  = 5.2899 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   160
# Train_cost  = 6.1857 | Test_cost  = 5.2877 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   161
# Train_cost  = 6.1818 | Test_cost  = 5.2856 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   162
# Train_cost  = 6.1778 | Test_cost  = 5.2836 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   163
# Train_cost  = 6.1739 | Test_cost  = 5.2816 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   164
# Train_cost  = 6.1701 | Test_cost  = 5.2797 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   165
# Train_cost  = 6.1663 | Test_cost  = 5.2780 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   166
# Train_cost  = 6.1625 | Test_cost  = 5.2762 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   167
# Train_cost  = 6.1588 | Test_cost  = 5.2746 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   168
# Train_cost  = 6.1551 | Test_cost  = 5.2730 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   169
# Train_cost  = 6.1514 | Test_cost  = 5.2715 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   170
# Train_cost  = 6.1477 | Test_cost  = 5.2700 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# ...
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   186
# Train_cost  = 6.0921 | Test_cost  = 5.2518 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   187
# Train_cost  = 6.0887 | Test_cost  = 5.2510 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   188
# Train_cost  = 6.0853 | Test_cost  = 5.2501 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   189
# Train_cost  = 6.0819 | Test_cost  = 5.2493 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   190
# Train_cost  = 6.0785 | Test_cost  = 5.2485 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   191
# Train_cost  = 6.0751 | Test_cost  = 5.2477 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   192
# Train_cost  = 6.0716 | Test_cost  = 5.2469 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   193
# Train_cost  = 6.0682 | Test_cost  = 5.2462 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   194
# Train_cost  = 6.0648 | Test_cost  = 5.2455 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   195
# Train_cost  = 6.0613 | Test_cost  = 5.2448 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   196
# Train_cost  = 6.0578 | Test_cost  = 5.2442 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   197
# Train_cost  = 6.0543 | Test_cost  = 5.2436 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   198
# Train_cost  = 6.0508 | Test_cost  = 5.2429 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   199
# Train_cost  = 6.0473 | Test_cost  = 5.2424 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   200
# Train_cost  = 6.0437 | Test_cost  = 5.2418 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   201
# Train_cost  = 6.0401 | Test_cost  = 5.2413 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   202
# Train_cost  = 6.0365 | Test_cost  = 5.2408 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   203
# Train_cost  = 6.0329 | Test_cost  = 5.2403 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   204
# Train_cost  = 6.0292 | Test_cost  = 5.2399 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   205
# Train_cost  = 6.0255 | Test_cost  = 5.2395 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   206
# Train_cost  = 6.0217 | Test_cost  = 5.2391 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   207
# Train_cost  = 6.0179 | Test_cost  = 5.2387 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   208
# Train_cost  = 6.0140 | Test_cost  = 5.2384 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   209
# Train_cost  = 6.0101 | Test_cost  = 5.2380 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   210
# Train_cost  = 6.0062 | Test_cost  = 5.2378 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   211
# Train_cost  = 6.0022 | Test_cost  = 5.2375 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   212
# Train_cost  = 5.9981 | Test_cost  = 5.2373 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   213
# Train_cost  = 5.9940 | Test_cost  = 5.2371 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   214
# Train_cost  = 5.9898 | Test_cost  = 5.2369 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   215
# Train_cost  = 5.9855 | Test_cost  = 5.2367 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   216
# Train_cost  = 5.9812 | Test_cost  = 5.2365 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   217
# Train_cost  = 5.9768 | Test_cost  = 5.2364 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   218
# Train_cost  = 5.9723 | Test_cost  = 5.2363 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   219
# Train_cost  = 5.9677 | Test_cost  = 5.2361 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   220
# Train_cost  = 5.9630 | Test_cost  = 5.2360 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   221
# Train_cost  = 5.9583 | Test_cost  = 5.2359 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   222
# Train_cost  = 5.9534 | Test_cost  = 5.2357 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   223
# Train_cost  = 5.9484 | Test_cost  = 5.2356 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   224
# Train_cost  = 5.9433 | Test_cost  = 5.2354 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   225
# Train_cost  = 5.9381 | Test_cost  = 5.2352 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   226
# Train_cost  = 5.9328 | Test_cost  = 5.2349 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   227
# Train_cost  = 5.9274 | Test_cost  = 5.2347 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   228
# Train_cost  = 5.9219 | Test_cost  = 5.2344 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   229
# Train_cost  = 5.9163 | Test_cost  = 5.2340 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   230
# Train_cost  = 5.9105 | Test_cost  = 5.2337 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   231
# Train_cost  = 5.9047 | Test_cost  = 5.2333 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   232
# Train_cost  = 5.8989 | Test_cost  = 5.2330 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   233
# Train_cost  = 5.8929 | Test_cost  = 5.2327 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   234
# Train_cost  = 5.8870 | Test_cost  = 5.2324 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   235
# Train_cost  = 5.8810 | Test_cost  = 5.2323 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   236
# Train_cost  = 5.8750 | Test_cost  = 5.2322 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   237
# Train_cost  = 5.8690 | Test_cost  = 5.2324 |
# ==> EarlyStop patience =  1 | Best test_cost: 5.2322
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   238
# Train_cost  = 5.8630 | Test_cost  = 5.2327 |
# ==> EarlyStop patience =  2 | Best test_cost: 5.2322
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   239
# Train_cost  = 5.8570 | Test_cost  = 5.2333 |
# ==> EarlyStop patience =  3 | Best test_cost: 5.2322
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   240
# Train_cost  = 5.8511 | Test_cost  = 5.2341 |
# ==> EarlyStop patience =  4 | Best test_cost: 5.2322
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   241
# Train_cost  = 5.8452 | Test_cost  = 5.2351 |
# ==> EarlyStop patience =  5 | Best test_cost: 5.2322
# ==> Execute Early Stopping at epoch: 241 | Best test_cost: 5.2322
# ==> Best model is saved at model

# %%
from luwiji.rnn import illustration

# %%
illustration.forecast

# %% [markdown]
# forcast untuk data time series itu sangat susah untuk diwujudkan dalam memprediksi dalam jangka panjang, karna apa? karna coba kita pahami illustrasi diatas, dimana pada saat training (menggunakan data untuk prediksi) model kita menggunakan data hari senin untuk memprediksi data hari selasa yang mana data hari selasa kita udah ada dalam dataset training kita, maka nya machine dapat memprediksi data yang ada (ya karna dia update weight, backprop, dll), tapi coba kita telaah lebih lanjut kalau misal nya kita hanya punya data yang dipelajari sampe hari rabu, kita coba untuk menggunakan insight dari data hari seni - rabu itu untuk memprediksi hari kamis dan selanjut nya, maka secara logika model machine kita akan kesusahan atau memiliki error prediksi yang tinggi, karna apa? karna informasi dari data data lalu (senin - rabu) itu gak terlalu bermakna, logika nya gini deh "kalau saya tau suhu di hari rabu, apakah saya bisa tau suhu di hari kamis? kemungkinan besar kita akan salah memprediksi nya" karna apa? karna informasi dari kita hanya mempelajari data data sebelum nya belum menjamin dapat memprediksi data data dikemudian hari selama nya.
# * maka dari itu kita perlu membuat data kita lebih bermakna, seperti kita bagi data misal nya berdasarkan quarter dalam satu tahun, maka itu setidak nya memberikan pola baru kepada machine dalam mempelajari pola.
# * menggunakan metode pengembangan dari Recurrent Neural Network juga bisa menjadi solusi nya

# %%
from utils import data4pred,pred4pred

# %%
train_forecast_set = TimeSeriesDataset(ts_train,"Temp",1)
trainforcastloader= DataLoader(train_forecast_set)
test_forecast_set = TimeSeriesDataset(ts_test,"Temp",1)
testforcastloader= DataLoader(test_forecast_set)
# Out:
# (N, S, F): (2919, 1, 1)
# Note: last 0 data excluded
#
# (N, S, F): (729, 1, 1)
# Note: last 0 data excluded

# %%
# data4pred
plt.figure(figsize=(15,10))

plt.subplot(211)
data4pred(model,train_forecast_set,trainforcastloader,device)
plt.title("train")


plt.subplot(212)
data4pred(model,test_forecast_set,testforcastloader,device)
plt.title("test")
# Out:
# C:\Users\Rahmat\anaconda3\envs\jcop\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'test')

# %%
plt.figure(figsize=(15,5))

pred4pred(model,test_forecast_set,testforcastloader,device)
plt.title("test")
# Out:
# Text(0.5, 1.0, 'test')
