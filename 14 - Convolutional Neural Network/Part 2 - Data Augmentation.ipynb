# %%
from torchvision import transforms
from luwiji.cnn import illustration

# %% [markdown]
# # Data Augmentation
#
# augmentasi: Sedikit mengubah data asli
# - meningkatkan generality (mengurangi overfit)<br>
# - menambah data<br>
#
# **It is a best practice to perform data augmentation when possible.**

# %%
img = illustration.img
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=386x288 at 0x1C8ED5A4348>

# %% [markdown]
# ### Random Crop

# %%
crop = transforms.RandomCrop(256)
crop(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256 at 0x1C8ED628EC8>

# %% [markdown]
# ### Random Flip

# %%
hflip = transforms.RandomHorizontalFlip()
hflip(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x1C8ED62E6C8>

# %%
vflip = transforms.RandomVerticalFlip()
vflip(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x1C8ED62EC88>

# %% [markdown]
# ### Random Rotation

# %%
rotate = transforms.RandomRotation(10)
rotate(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x1C8ED62E788>

# %% [markdown]
# ### Random ResizedCrop

# %%
resize = transforms.RandomResizedCrop(256,scale=(0.5,1.0))
resize(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256 at 0x1C8ED628CC8>

# %% [markdown]
# ### Random Affine

# %%
translate = transforms.RandomAffine(0, translate=(0.3, 0.3))
translate(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x1C8ECFA7648>

# %%
shear = transforms.RandomAffine(0, shear=10)
shear(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x1C8ED62EC08>

# %%
affine = transforms.RandomAffine(5, translate=(0.1, 0.1), shear=10)
affine(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x1C8ED62E448>

# %% [markdown]
# ### Color Jitter

# %%
brightness = transforms.ColorJitter(brightness=0.3)
brightness(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x1C8ED63AD48>

# %%
contrast = transforms.ColorJitter(contrast=0.3)
contrast(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x1C8ED632888>

# %% [markdown]
# # 1 Gambar seakan" menjadi banyak

# %%
import matplotlib.pyplot as plt
from luwiji.cnn import illustration

img = illustration.img

# %%
transform = transforms.Compose([
    transforms.RandomRotation(15),
    transforms.RandomResizedCrop((224, 224), scale=(0.7, 1)),
    transforms.ColorJitter((0.7, 1.3))
])

fig, axes = plt.subplots(5, 5, figsize=(15, 15))
fig.subplots_adjust(wspace=0.1, hspace=0.1)
for ax in axes.flatten():
    ax.imshow(img)
    ax.axis("off")

# %% [markdown]
# # Diskusi
#
# Apakah ada kasus dimana augmentasi tertentu tidak boleh dipakai?
