# %%
from torchvision import transforms
from luwiji.cnn import illustration

# %% [markdown]
# # Data Augmentation
#
# augmentasi: Sedikit mengubah data asli
# - meningkatkan generality (mengurangi overfit)<br>
# - menambah data<br>
#
# **It is a best practice to perform data augmentation when possible.**

# %%
img = illustration.img
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=386x288 at 0x22DF729ED48>

# %% [markdown]
# ### Random Crop

# %%
crop = transforms.RandomCrop(256)
crop(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256 at 0x22DF75D5AC8>

# %% [markdown]
# ### Random Flip

# %%
hflip = transforms.RandomHorizontalFlip()
hflip(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x22DF9FBD948>

# %%
vflip = transforms.RandomVerticalFlip()
vflip(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=386x288 at 0x22DF729ED48>

# %% [markdown]
# ### Random Rotation

# %%
rotate = transforms.RandomRotation(10)
rotate(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x22DF76E5648>

# %% [markdown]
# ### Random ResizedCrop

# %%
resize = transforms.RandomResizedCrop(256)
resize(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256 at 0x22DF6F64308>

# %% [markdown]
# ### Random Affine

# %%
translate = transforms.RandomAffine(0, translate=(0.3, 0.3))
translate(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x22DF76E5248>

# %%
shear = transforms.RandomAffine(0, shear=10)
shear(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x22DF76E5FC8>

# %%
affine = transforms.RandomAffine(5, translate=(0.1, 0.1), shear=10)
affine(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x22DF3CB9188>

# %% [markdown]
# ### Color Jitter

# %%
brightness = transforms.ColorJitter(brightness=0.3)
brightness(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x22DF75D87C8>

# %%
contrast = transforms.ColorJitter(contrast=0.3)
contrast(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x22DF75D8E48>

# %% [markdown]
# # 1 Gambar seakan" menjadi banyak

# %%
import matplotlib.pyplot as plt
from luwiji.cnn import illustration

img = illustration.img

# %%
transform = transforms.Compose([
    transforms.RandomRotation(15),
    transforms.RandomResizedCrop((224, 224), scale=(0.7, 1)),
    transforms.ColorJitter((0.7, 1.3))
])

fig, axes = plt.subplots(5, 5, figsize=(15, 15))
fig.subplots_adjust(wspace=0.1, hspace=0.1)
for ax in axes.flatten():
    ax.imshow(t(img))
    ax.axis("off")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e76c31d5fd21> in <module>
#       8 fig.subplots_adjust(wspace=0.1, hspace=0.1)
#       9 for ax in axes.flatten():
# ---> 10     ax.imshow(t(img))
#      11     ax.axis("off")
#
# NameError: name 't' is not defined

# %% [markdown]
# # Diskusi
#
# Apakah ada kasus dimana augmentasi tertentu tidak boleh dipakai?
